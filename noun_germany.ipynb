# %%
import pandas as pd

# %%
df=pd.read_csv(r"D:\Eup\fazzta\german-nouns\german_nouns\nouns.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15948\1006849671.py:1: DtypeWarning: Columns (5,6,8,11,12,20,21,29,30,38,39,47,48,56,57,65,66,74,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"D:\Eup\fazzta\german-nouns\german_nouns\nouns.csv")

# %%
df
# Out:
#                    lemma                          pos genus genus 1 genus 2  \
# 0                 -algie  Gebundenes Lexem,Substantiv     f     NaN     NaN
# 1                   -ant      Affix,Substantiv,Suffix   NaN       m       n
# 2                   -anz      Affix,Substantiv,Suffix     f     NaN     NaN
# 3                  -chen      Affix,Substantiv,Suffix     n     NaN     NaN
# 4                -elchen      Affix,Substantiv,Suffix     n     NaN     NaN
# ...                  ...                          ...   ...     ...     ...
# 102439           Ḫāriǧit                   Substantiv   NaN     NaN     NaN
# 102440       ’Ndrangheta                   Substantiv     f     NaN     NaN
# 102441         ’Sgebengu                   Substantiv     m     NaN     NaN
# 102442     ’s-Gravenhage           Substantiv,Toponym   NaN     NaN     NaN
# 102443  ’s-Hertogenbosch           Substantiv,Toponym   NaN     NaN     NaN
#
# ...
